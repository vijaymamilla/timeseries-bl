# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, RNN

import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams["figure.figsize"] = (9,6)

# %%
np.random.seed(42)
tf.random.set_seed(42)
tf.keras.utils.set_random_seed(42)

# %%
df_raw = pd.read_csv('data/dhaka_raw.csv',index_col=['datetime'],parse_dates=True)

# %%
df_raw.head()
# Out:
#             tempmax_x  tempmin_x  temp  feelslikemax_x  feelslikemin_x  \
# datetime
# 2013-01-01       25.0       11.4  17.8            25.0            11.4
# 2013-02-01       25.0       12.4  18.7            25.0            12.4
# 2013-03-01       25.0       15.9  19.1            25.0            15.9
# 2013-04-01       25.0       15.9  20.0            25.0            15.9
# 2013-05-01       25.0       15.0  19.1            25.0            15.0
#
#             feelslike   dew  humidity  precipprob  precipcover  ...  \
# datetime                                                        ...
# 2013-01-01       17.8  12.2      73.1           0         0.00  ...
# 2013-02-01       18.7  13.0      71.5           0         0.00  ...
# 2013-03-01       19.1  13.9      73.3         100         8.33  ...
# 2013-04-01       20.0  15.7      77.6           0         0.00  ...
# 2013-05-01       19.1  13.9      73.5           0         0.00  ...
#
#             solarenergy  uvindex  apparent_temperature_mean  \
# datetime
# 2013-01-01         14.7        7                       17.0
# 2013-02-01         14.3        6                       18.2
# 2013-03-01          8.1        3                       19.1
# 2013-04-01         14.2        6                       19.7
# 2013-05-01         14.9        7                       17.8
#
#             precipitation_sum  precipitation_hours  windspeed_y  \
# datetime
# 2013-01-01                0.0                    0         10.5
# 2013-02-01                0.0                    0          9.5
# 2013-03-01                0.0                    0          6.8
# 2013-04-01                0.0                    0          8.9
# 2013-05-01                0.0                    0          9.3
#
#             et0_fao_evapotranspiration  river_discharge  rain_sum  precip
# datetime
# 2013-01-01                        3.01             0.22       0.0     0.0
# 2013-02-01                        2.90             0.22       0.0     0.0
# 2013-03-01                        1.26             0.22       0.0     0.2
# 2013-04-01                        2.43             0.22       0.0     0.0
# 2013-05-01                        3.00             0.22       0.0     0.0
#
# [5 rows x 26 columns]

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3881 entries, 2013-01-01 to 2023-08-17
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tempmax_x                   3881 non-null   float64
#  1   tempmin_x                   3881 non-null   float64
#  2   temp                        3881 non-null   float64
#  3   feelslikemax_x              3881 non-null   float64
#  4   feelslikemin_x              3881 non-null   float64
#  5   feelslike                   3881 non-null   float64
#  6   dew                         3881 non-null   float64
#  7   humidity                    3881 non-null   float64
#  8   precipprob                  3881 non-null   int64
#  9   precipcover                 3881 non-null   float64
#  10  windspeed_x                 3881 non-null   float64
#  11  winddir                     3881 non-null   float64
#  12  sealevelpressure            3878 non-null   float64
#  13  cloudcover                  3881 non-null   float64
#  14  visibility                  3881 non-null   float64
#  15  solarradiation              3881 non-null   float64
#  16  solarenergy                 3881 non-null   float64
#  17  uvindex                     3881 non-null   int64
#  18  apparent_temperature_mean   3881 non-null   float64
#  19  precipitation_sum           3881 non-null   float64
#  20  precipitation_hours         3881 non-null   int64
#  21  windspeed_y                 3881 non-null   float64
#  22  et0_fao_evapotranspiration  3881 non-null   float64
#  23  river_discharge             3881 non-null   float64
#  24  rain_sum                    3881 non-null   float64
#  25  precip                      3881 non-null   float64
# dtypes: float64(23), int64(3)
# memory usage: 818.6 KB

# %%
df_raw.isnull().sum()
# Out:
# tempmax_x                     0
# tempmin_x                     0
# temp                          0
# feelslikemax_x                0
# feelslikemin_x                0
# feelslike                     0
# dew                           0
# humidity                      0
# precipprob                    0
# precipcover                   0
# windspeed_x                   0
# winddir                       0
# sealevelpressure              3
# cloudcover                    0
# visibility                    0
# solarradiation                0
# solarenergy                   0
# uvindex                       0
# apparent_temperature_mean     0
# precipitation_sum             0
# precipitation_hours           0
# windspeed_y                   0
# et0_fao_evapotranspiration    0
# river_discharge               0
# rain_sum                      0
# precip                        0
# dtype: int64

# %%
df_raw['sealevelpressure']
# Out:
# datetime
# 2013-01-01    1011.5
# 2013-02-01    1012.1
# 2013-03-01    1012.9
# 2013-04-01    1012.7
# 2013-05-01    1011.4
#                ...
# 2023-08-13    1003.7
# 2023-08-14    1004.3
# 2023-08-15    1004.1
# 2023-08-16    1003.5
# 2023-08-17    1002.8
# Name: sealevelpressure, Length: 3881, dtype: float64

# %%
df = df_raw.fillna(method='ffill')

# %%
df.isnull().sum()
# Out:
# tempmax_x                     0
# tempmin_x                     0
# temp                          0
# feelslikemax_x                0
# feelslikemin_x                0
# feelslike                     0
# dew                           0
# humidity                      0
# precipprob                    0
# precipcover                   0
# windspeed_x                   0
# winddir                       0
# sealevelpressure              0
# cloudcover                    0
# visibility                    0
# solarradiation                0
# solarenergy                   0
# uvindex                       0
# apparent_temperature_mean     0
# precipitation_sum             0
# precipitation_hours           0
# windspeed_y                   0
# et0_fao_evapotranspiration    0
# river_discharge               0
# rain_sum                      0
# precip                        0
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(13,6))

ax.plot(df['rain_sum'])
ax.set_xlabel('Date')
ax.set_ylabel('Rain')

fig.autofmt_xdate()
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(13,6))

ax.plot(df['river_discharge'])
ax.set_xlabel('Date')
ax.set_ylabel('River Discharge')

fig.autofmt_xdate()
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(13,6))

ax.plot(df['precip'])
ax.set_xlabel('Date')
ax.set_ylabel('Precip')

fig.autofmt_xdate()
plt.tight_layout()

# %%
df.describe().transpose()
# Out:
#                              count         mean        std     min      25%  \
# tempmax_x                   3881.0    31.081912   3.613910   16.00    29.00
# tempmin_x                   3881.0    23.099794   4.624058    7.00    19.50
# temp                        3881.0    26.728549   3.915996   11.40    24.10
# feelslikemax_x              3881.0    35.402834   6.699066   16.00    29.40
# feelslikemin_x              3881.0    24.272610   5.963065    5.50    19.50
# feelslike                   3881.0    29.453440   6.160665   10.90    24.10
# dew                         3881.0    20.673254   4.487165    6.70    16.80
# humidity                    3881.0    71.219660   9.094490   33.20    65.50
# precipprob                  3881.0    56.737954  49.550304    0.00     0.00
# precipcover                 3881.0    38.365287  41.197084    0.00     0.00
# windspeed_x                 3881.0    19.162948  11.089741    0.00    14.80
# winddir                     3881.0   193.678073  89.638684    0.10   131.90
# sealevelpressure            3881.0  1007.852255   5.493192  991.80  1003.40
# cloudcover                  3881.0    51.516954  30.832490    0.00    23.00
# visibility                  3881.0     3.769415   0.790021    0.70     3.60
# solarradiation              3881.0   204.666323  54.374143    3.80   170.30
# solarenergy                 3881.0    17.665421   4.704260    0.20    14.70
# uvindex                     3881.0     7.208709   1.741026    0.00     6.00
# apparent_temperature_mean   3881.0    28.760706   5.979069   11.70    23.60
# precipitation_sum           3881.0     4.983535   9.928966    0.00     0.00
# precipitation_hours         3881.0     5.346818   6.624135    0.00     0.00
# windspeed_y                 3881.0    12.580984   4.830484    4.00     9.00
# et0_fao_evapotranspiration  3881.0     3.574190   1.116134    0.56     2.88
# river_discharge             3881.0     1.295872   1.370404    0.20     0.31
# rain_sum                    3881.0     4.983535   9.928966    0.00     0.00
# precip                      3881.0     8.035455  16.285925    0.00     0.00
#
#                                 50%      75%      max
# tempmax_x                     32.00    34.00    42.00
# tempmin_x                     25.00    27.00    30.00
# temp                          28.00    29.70    34.10
# feelslikemax_x                36.80    40.70    54.60
# feelslikemin_x                25.00    30.10    37.40
# feelslike                     30.70    34.70    41.70
# dew                           22.20    24.60    26.80
# humidity                      71.20    77.50    94.10
# precipprob                   100.00   100.00   100.00
# precipcover                   20.83    83.33   100.00
# windspeed_x                   18.40    22.30   244.80
# winddir                      178.50   284.30   360.00
# sealevelpressure            1008.00  1012.50  1019.40
# cloudcover                    58.80    78.90    99.80
# visibility                     4.00     4.10    31.00
# solarradiation               206.40   245.20   335.90
# solarenergy                   17.80    21.20    29.00
# uvindex                        7.00     8.00    10.00
# apparent_temperature_mean     31.10    33.50    39.50
# precipitation_sum              0.50     5.90   150.00
# precipitation_hours            2.00     9.00    24.00
# windspeed_y                   11.00    15.30    42.40
# et0_fao_evapotranspiration     3.49     4.26     7.41
# river_discharge                0.85     1.81    28.11
# rain_sum                       0.50     5.90   150.00
# precip                         0.90     9.40   209.50

# %%
n = len(df)

# Split 70:20:10 (train:validation:test)
train_df = df[0:int(n*0.7)]
val_df = df[int(n*0.7):int(n*0.9)]
test_df = df[int(n*0.9):]

train_df.shape, val_df.shape, test_df.shape
# Out:
# ((2716, 26), (776, 26), (389, 26))

# %%
RD_max_train = np.max(train_df['river_discharge'])
RD_min_train = np.min(train_df['river_discharge'])
RD_max_test = np.max(test_df['river_discharge'])
RD_min_test = np.min(test_df['river_discharge'])

R_max_train = np.max(train_df['rain_sum'])
R_min_train = np.min(train_df['rain_sum'])
R_max_test = np.max(test_df['rain_sum'])
R_min_test = np.min(test_df['rain_sum'])

P_max_train = np.max(train_df['precip'])
P_min_train = np.min(train_df['precip'])
P_max_test = np.max(test_df['precip'])
P_min_test = np.min(test_df['precip'])

# %%
print(RD_max_train,RD_min_train,RD_max_test,RD_min_test)

print(R_max_train, R_min_train,R_max_test,R_min_test)
print(P_max_train, P_min_train,P_max_test,P_min_test)
# Out:
# 11.94 0.2 28.11 0.25
# 150.0 0.0 98.0 0.0
# 209.5 0.0 156.0 0.0

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(train_df)
test_scaler = MinMaxScaler()
test_scaler.fit(test_df)

train_df[train_df.columns] = scaler.transform(train_df[train_df.columns])
val_df[val_df.columns] = scaler.transform(val_df[val_df.columns])
test_df[test_df.columns] = test_scaler.transform(test_df[test_df.columns])

# %%
train_df.head()
# Out:
#             tempmax_x  tempmin_x      temp  feelslikemax_x  feelslikemin_x  \
# datetime
# 2013-01-01   0.346154   0.191304  0.281938        0.233161        0.184953
# 2013-02-01   0.346154   0.234783  0.321586        0.233161        0.216301
# 2013-03-01   0.346154   0.386957  0.339207        0.233161        0.326019
# 2013-04-01   0.346154   0.386957  0.378855        0.233161        0.326019
# 2013-05-01   0.346154   0.347826  0.339207        0.233161        0.297806
#
#             feelslike       dew  humidity  precipprob  precipcover  ...  \
# datetime                                                            ...
# 2013-01-01   0.224026  0.273632  0.655172         0.0       0.0000  ...
# 2013-02-01   0.253247  0.313433  0.628900         0.0       0.0000  ...
# 2013-03-01   0.266234  0.358209  0.658456         1.0       0.0833  ...
# 2013-04-01   0.295455  0.447761  0.729064         0.0       0.0000  ...
# 2013-05-01   0.266234  0.358209  0.661741         0.0       0.0000  ...
#
#             solarenergy  uvindex  apparent_temperature_mean  \
# datetime
# 2013-01-01     0.451064    0.625                   0.197761
# 2013-02-01     0.434043    0.500                   0.242537
# 2013-03-01     0.170213    0.125                   0.276119
# 2013-04-01     0.429787    0.500                   0.298507
# 2013-05-01     0.459574    0.625                   0.227612
#
#             precipitation_sum  precipitation_hours  windspeed_y  \
# datetime
# 2013-01-01                0.0                  0.0     0.160526
# 2013-02-01                0.0                  0.0     0.134211
# 2013-03-01                0.0                  0.0     0.063158
# 2013-04-01                0.0                  0.0     0.118421
# 2013-05-01                0.0                  0.0     0.128947
#
#             et0_fao_evapotranspiration  river_discharge  rain_sum    precip
# datetime
# 2013-01-01                    0.354839         0.001704       0.0  0.000000
# 2013-02-01                    0.338710         0.001704       0.0  0.000000
# 2013-03-01                    0.098240         0.001704       0.0  0.000955
# 2013-04-01                    0.269795         0.001704       0.0  0.000000
# 2013-05-01                    0.353372         0.001704       0.0  0.000000
#
# [5 rows x 26 columns]

# %%
train_df.describe().transpose()
# Out:
#                              count      mean       std  min       25%  \
# tempmax_x                   2716.0  0.575152  0.141023  0.0  0.500000
# tempmin_x                   2716.0  0.682838  0.202381  0.0  0.521739
# temp                        2716.0  0.661468  0.175290  0.0  0.546256
# feelslikemax_x              2716.0  0.496765  0.177618  0.0  0.341969
# feelslikemin_x              2716.0  0.571624  0.186034  0.0  0.423197
# feelslike                   2716.0  0.588580  0.203480  0.0  0.418831
# dew                         2716.0  0.685028  0.235694  0.0  0.472637
# humidity                    2716.0  0.634238  0.157206  0.0  0.536946
# precipprob                  2716.0  0.553756  0.497193  0.0  0.000000
# precipcover                 2716.0  0.401555  0.423632  0.0  0.000000
# windspeed_x                 2716.0  0.077469  0.044404  0.0  0.060458
# winddir                     2716.0  0.530047  0.256549  0.0  0.353170
# sealevelpressure            2716.0  0.576525  0.206764  0.0  0.408088
# cloudcover                  2716.0  0.512218  0.304352  0.0  0.234218
# visibility                  2716.0  0.101485  0.028697  0.0  0.095710
# solarradiation              2716.0  0.568875  0.192823  0.0  0.443782
# solarenergy                 2716.0  0.567357  0.193650  0.0  0.442553
# uvindex                     2716.0  0.632640  0.210507  0.0  0.500000
# apparent_temperature_mean   2716.0  0.628229  0.221316  0.0  0.436567
# precipitation_sum           2716.0  0.033791  0.067697  0.0  0.000000
# precipitation_hours         2716.0  0.215237  0.272625  0.0  0.000000
# windspeed_y                 2716.0  0.213398  0.127196  0.0  0.121053
# et0_fao_evapotranspiration  2716.0  0.432361  0.160848  0.0  0.334311
# river_discharge             2716.0  0.094279  0.112703  0.0  0.009370
# rain_sum                    2716.0  0.033791  0.067697  0.0  0.000000
# precip                      2716.0  0.042029  0.084997  0.0  0.000000
#
#                                  50%       75%  max
# tempmax_x                   0.615385  0.680769  1.0
# tempmin_x                   0.739130  0.860870  1.0
# temp                        0.713656  0.797357  1.0
# feelslikemax_x              0.520725  0.639896  1.0
# feelslikemin_x              0.579937  0.753135  1.0
# feelslike                   0.613636  0.769481  1.0
# dew                         0.751244  0.900498  1.0
# humidity                    0.638752  0.747126  1.0
# precipprob                  1.000000  1.000000  1.0
# precipcover                 0.208300  0.875000  1.0
# windspeed_x                 0.075163  0.091095  1.0
# winddir                     0.486930  0.804296  1.0
# sealevelpressure            0.591912  0.750000  1.0
# cloudcover                  0.568637  0.782565  1.0
# visibility                  0.108911  0.115512  1.0
# solarradiation              0.566398  0.718360  1.0
# solarenergy                 0.565957  0.719149  1.0
# uvindex                     0.625000  0.750000  1.0
# apparent_temperature_mean   0.708955  0.805970  1.0
# precipitation_sum           0.002667  0.041500  1.0
# precipitation_hours         0.083333  0.375000  1.0
# windspeed_y                 0.171053  0.286842  1.0
# et0_fao_evapotranspiration  0.422287  0.530792  1.0
# river_discharge             0.055366  0.139693  1.0
# rain_sum                    0.002667  0.041500  1.0
# precip                      0.003819  0.048210  1.0

# %%
train_df.to_csv('data/train.csv')
val_df.to_csv('data/val.csv')
test_df.to_csv('data/test.csv')

# %%
train_df = pd.read_csv('data/train.csv', index_col='datetime',parse_dates=True)
val_df = pd.read_csv('data/val.csv', index_col='datetime',parse_dates=True)
test_df = pd.read_csv('data/test.csv', index_col='datetime',parse_dates=True)

print(train_df.shape, val_df.shape, test_df.shape)
# Out:
# (2716, 26) (776, 26) (389, 26)

# %%
def format_timeseries_data(df, input_length, output_length, target_names):
    
    if target_names is not None:
        target_indices = {name: i for i, name in enumerate(target_names)}
    col_indices = {name: i for i, name in enumerate(df.columns)}
    
    total_length = input_length + output_length
    
    input_slice = slice(0, input_length)
    output_slice = slice(input_length, None)
    
    data = np.array(df, dtype=np.float32)
    ds = tf.keras.preprocessing.timeseries_dataset_from_array(
        data=data,
        targets=None,
        sequence_length=total_length,
        sequence_stride=1,
        shuffle=False,
        batch_size=32
    )
    
    def split_to_input_output(x):
            
        inputs = x[:, input_slice, :]
        outputs = x[:, output_slice, :]
        
        if target_names is not None:
            outputs = tf.stack(
                [outputs[:,:,col_indices[name]] for name in target_names],
                axis=-1
            )

        inputs.set_shape([None, input_length, None])
        outputs.set_shape([None, output_length, None])
    
        return inputs, outputs
    
    ds = ds.map(split_to_input_output)
    
    return ds

# %%
def train_model(model, train_ds, val_ds, patience=5, max_epochs=50):
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=patience, mode='min')
    
    model.compile(loss=MeanSquaredError(), optimizer=Adam(), metrics=[MeanAbsoluteError()])
    
    history = model.fit(train_ds, epochs=max_epochs, validation_data=val_ds, callbacks=[early_stopping])
    
    return history

# %%
def plot_history(history):

    fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)

    ax1.plot(history.history['loss'], label='Train')
    ax1.plot(history.history['val_loss'], label='Validation')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss')
    ax1.set_title('Loss')
    ax1.legend(loc='best')

    ax2.plot(history.history['mean_absolute_error'], label='Train')
    ax2.plot(history.history['val_mean_absolute_error'], label='Validation')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('MAE')
    ax2.set_title('Mean absolute error')
    ax2.legend(loc='best')

    plt.tight_layout()

# %%
def plot_predictions(model, sample_batch, model_type):
    
    inputs, outputs = sample_batch
    preds = model(inputs)
    
    
    if model_type == 'multi_output':
        
        fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1)
        
        RD_actual_scaled = outputs.numpy().flatten()[0::2]
        RD_actual = RD_actual_scaled * (RD_max_test - RD_min_test) + RD_min_test
        
        RD_predictions_scaled = preds.numpy().flatten()[0::2]
        RD_predictions = RD_predictions_scaled * (RD_max_train - RD_min_train) + RD_min_train

        R_actual_scaled = outputs.numpy().flatten()[1::2]
        R_actual = R_actual_scaled * (R_max_test - R_min_test) + R_min_test
        
        R_predictions_scaled = preds.numpy().flatten()[1::2]
        R_predictions = R_predictions_scaled * (R_max_train - R_min_train) + R_min_train
        
        ax1.plot(RD_actual, label='Actual')
        ax1.plot(RD_predictions, label='Predicted')
        ax1.set_xlabel('Time')
        ax1.set_ylabel('River Discharge')
        ax1.legend(loc='best')
        ax1.set_title('Predictions on a sample batch')
        
        ax2.plot(R_actual, label='Actual')
        ax2.plot(R_predictions, label='Predicted')
        ax2.set_xlabel('Time')
        ax2.set_ylabel('Rain Sum')
        ax2.legend(loc='best')
       
        
        
    plt.tight_layout()

# %% [markdown]
# Multi-output model

# %%
train_ds_mo = format_timeseries_data(train_df, 14, 14, ['river_discharge', 'rain_sum','precip'])
val_ds_mo = format_timeseries_data(val_df, 14, 14, ['river_discharge', 'rain_sum','precip'])
test_ds_mo = format_timeseries_data(test_df, 14, 14, ['river_discharge', 'rain_sum','precip'])

mo_sample_batch = next(iter(test_ds_mo))

# %%
mo_dnn = Sequential([
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(3)
])

mo_dnn_history = train_model(mo_dnn, train_ds_mo, val_ds_mo)
# Out:
# Epoch 1/50
# 85/85 [==============================] - 1s 5ms/step - loss: 0.0159 - mean_absolute_error: 0.0849 - val_loss: 0.0051 - val_mean_absolute_error: 0.0495
# Epoch 2/50
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0542 - val_loss: 0.0047 - val_mean_absolute_error: 0.0463
# Epoch 3/50
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0537 - val_loss: 0.0047 - val_mean_absolute_error: 0.0472
# Epoch 4/50
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0074 - mean_absolute_error: 0.0525 - val_loss: 0.0045 - val_mean_absolute_error: 0.0452
# Epoch 5/50
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_absolute_error: 0.0519 - val_loss: 0.0045 - val_mean_absolute_error: 0.0467
# Epoch 6/50
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0071 - mean_absolute_error: 0.0509 - val_loss: 0.0042 - val_mean_absolute_error: 0.0432
# Epoch 7/50
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0070 - mean_absolute_error: 0.0505 - val_loss: 0.0042 - val_mean_absolute_error: 0.0424
# Epoch 8/50
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0069 - mean_absolute_error: 0.0500 - val_loss: 0.0041 - val_mean_absolute_error: 0.0416
# Epoch 9/50
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0069 - mean_absolute_error: 0.0498 - val_loss: 0.0040 - val_mean_absolute_error: 0.0407
# Epoch 10/50
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0069 - mean_absolute_error: 0.0495 - val_loss: 0.0040 - val_mean_absolute_error: 0.0404
# Epoch 11/50
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0068 - mean_absolute_error: 0.0488 - val_loss: 0.0040 - val_mean_absolute_error: 0.0408
# Epoch 12/50
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0068 - mean_absolute_error: 0.0488 - val_loss: 0.0040 - val_mean_absolute_error: 0.0401
# Epoch 13/50
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0067 - mean_absolute_error: 0.0485 - val_loss: 0.0040 - val_mean_absolute_error: 0.0398
# Epoch 14/50
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0066 - mean_absolute_error: 0.0483 - val_loss: 0.0040 - val_mean_absolute_error: 0.0398
# Epoch 15/50
# 85/85 [==============================] - 0s 4ms/step - loss: 0.0066 - mean_absolute_error: 0.0480 - val_loss: 0.0040 - val_mean_absolute_error: 0.0398
# Epoch 16/50
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0066 - mean_absolute_error: 0.0478 - val_loss: 0.0040 - val_mean_absolute_error: 0.0393
# Epoch 17/50
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0065 - mean_absolute_error: 0.0475 - val_loss: 0.0040 - val_mean_absolute_error: 0.0394
# Epoch 18/50
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0065 - mean_absolute_error: 0.0474 - val_loss: 0.0040 - val_mean_absolute_error: 0.0390
# Epoch 19/50
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0065 - mean_absolute_error: 0.0472 - val_loss: 0.0040 - val_mean_absolute_error: 0.0390
# Epoch 20/50
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0065 - mean_absolute_error: 0.0470 - val_loss: 0.0040 - val_mean_absolute_error: 0.0393
# Epoch 21/50
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0065 - mean_absolute_error: 0.0469 - val_loss: 0.0040 - val_mean_absolute_error: 0.0393

# %%
plot_history(mo_dnn_history)

# %%
plot_predictions(mo_dnn, mo_sample_batch, 'multi_output')

# %% [markdown]
# Evaluation

# %%
def plot_evaluation(model_list, mae):
    
    fig, ax = plt.subplots()
    
    ax.bar(model_list, mae, width=0.3)
    ax.set_ylabel('MAE')
    ax.set_xlabel('Models')
    ax.set_ylim(0, max(mae)+0.15)
    for index, value in enumerate(mae):
        ax.text(x=index, y=value+0.005, s=str(round(value, 3)), ha='center')
    
    plt.tight_layout()

# %%
mo_lstm = Sequential([
    LSTM(128, return_sequences=True),
    Dense(3)
])

mo_lstm_history = train_model(mo_lstm, train_ds_mo, val_ds_mo)
# Out:
# Epoch 1/50
# 85/85 [==============================] - 3s 16ms/step - loss: 0.0161 - mean_absolute_error: 0.0807 - val_loss: 0.0058 - val_mean_absolute_error: 0.0562
# Epoch 2/50
# 85/85 [==============================] - 1s 11ms/step - loss: 0.0082 - mean_absolute_error: 0.0588 - val_loss: 0.0072 - val_mean_absolute_error: 0.0610
# Epoch 3/50
# 85/85 [==============================] - 1s 11ms/step - loss: 0.0082 - mean_absolute_error: 0.0598 - val_loss: 0.0055 - val_mean_absolute_error: 0.0518
# Epoch 4/50
# 85/85 [==============================] - 1s 11ms/step - loss: 0.0075 - mean_absolute_error: 0.0546 - val_loss: 0.0043 - val_mean_absolute_error: 0.0459
# Epoch 5/50
# 85/85 [==============================] - 1s 11ms/step - loss: 0.0070 - mean_absolute_error: 0.0513 - val_loss: 0.0042 - val_mean_absolute_error: 0.0450
# Epoch 6/50
# 85/85 [==============================] - 1s 11ms/step - loss: 0.0069 - mean_absolute_error: 0.0509 - val_loss: 0.0041 - val_mean_absolute_error: 0.0440
# Epoch 7/50
# 85/85 [==============================] - 1s 11ms/step - loss: 0.0069 - mean_absolute_error: 0.0506 - val_loss: 0.0041 - val_mean_absolute_error: 0.0435
# Epoch 8/50
# 85/85 [==============================] - 1s 11ms/step - loss: 0.0068 - mean_absolute_error: 0.0504 - val_loss: 0.0041 - val_mean_absolute_error: 0.0437
# Epoch 9/50
# 85/85 [==============================] - 1s 11ms/step - loss: 0.0067 - mean_absolute_error: 0.0503 - val_loss: 0.0042 - val_mean_absolute_error: 0.0444
# Epoch 10/50
# 85/85 [==============================] - 1s 11ms/step - loss: 0.0067 - mean_absolute_error: 0.0502 - val_loss: 0.0043 - val_mean_absolute_error: 0.0457
# Epoch 11/50
# 85/85 [==============================] - 1s 11ms/step - loss: 0.0066 - mean_absolute_error: 0.0501 - val_loss: 0.0045 - val_mean_absolute_error: 0.0472
# Epoch 12/50
# 85/85 [==============================] - 1s 11ms/step - loss: 0.0066 - mean_absolute_error: 0.0500 - val_loss: 0.0047 - val_mean_absolute_error: 0.0490

# %%
plot_history(mo_lstm_history)

# %%
plot_predictions(mo_lstm, mo_sample_batch, 'multi_output')

# %%
model_list = ['DNN','LSTM']

mo_mae = [0.0469,0.050]

plot_evaluation(model_list, mo_mae)

# %%
mo_lstm.save("lstm_dhaka_model.h5")
